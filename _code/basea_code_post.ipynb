# %% [markdown]
# ---
# title: tên bài viết
# author: tên người tạo
# date: yyyy-mm-dd
# categories: [category,category]
# tags: [tag1,tag2]
# math: true
# mermaid: true
# ---

# %% [markdown]
# # NỘI DUNG BÀI POST Ở ĐÂY
